# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.tri as mtri

# %%
def draw_BiLSTM_graph():
    
    MSRA = [91.12, 91.44, 91.59, 91.11, 91.45]
    Weibo = [52.84, 54.57, 54.22, 57.10, 57.11]
    Literature = [74.28, 75.26, 75.99,74.88, 75.19]
    Resume = [29.61, 32.13, 32.26, 46.21, 46.78]
    E_commerce = [79.17,79.85, 79.24, 78.18, 78.16]
    CLUENER = [75.31,76.48,76.85,71.55,72.63]
    Novel =[65.80,68.97, 67.08,57.24, 58.62]
    Finace = [88.34, 88.63, 88.64, 89.49, 90.29]
    
    x = ['char','1rad','3components','p_char','p_1rad']
    
    
    # draw
    plt.figure()
    plt.plot(x, MSRA, label='MSRA')
    plt.plot(x, Weibo, label='Weibo')
    plt.plot(x, Literature, label='Literature')
    plt.plot(x, Resume, label='Resume')
    plt.plot(x, E_commerce, label='E_commerce')
    plt.plot(x, CLUENER, label='CLUENER')
    plt.plot(x, Novel, label='Novel')
    plt.plot(x, Finace, label='Finace')
    
    plt.title('Model f1 scores')
    plt.xlabel('Model')
    plt.ylabel("F1 scores")
    plt.legend(loc='best')


#     ax1.plot(x, z1, marker='1', linestyle='-', color='r', label='dev_f1_last', linewidth=1)
#     ax1.plot(x, z3, marker='1', linestyle='-', color='b', label='dev_f1_ave', linewidth=1)
#     ax2.plot(x, z2, marker='2', linestyle='-', color='r', label='dev_loss_last', linewidth=1)
#     ax2.plot(x, z4, marker='2', linestyle='-', color='b', label='dev_loss_ave', linewidth=1)

    plt.show()

# %%
draw_BiLSTM_graph()

# %%
def draw_all_graph(output = "output.png"):
    
    x = ['char','1 rad','3 comps']
        
#     plt.title('Model f1 scores')
#     plt.xlabel('Model')
#     plt.ylabel("F1 scores")
#     plt.legend(loc='best')
    
    
    f = plt.figure(figsize=(15,6))
    f.tight_layout()
    plt.subplots_adjust(wspace = 0.4, hspace = 0.4)
    ax1 = f.add_subplot(241)
    ax2 = f.add_subplot(242)
    ax3 = f.add_subplot(243)
    ax4 = f.add_subplot(244)
    ax5 = f.add_subplot(245)
    ax6 = f.add_subplot(246)
    ax7 = f.add_subplot(247)
    ax8 = f.add_subplot(248)
    
    # MSRA
    z1_1_L = [91.12, 91.44, 91.59]
    z1_p_L = [91.11, 91.45, None]
    z1_1_C = [93.32, 93.71,93.85]
    z1_p_C = [92.31, 92.89, None]
    ax1.plot(x, z1_1_L, label='o_L',marker='1')
    ax1.plot(x, z1_p_L, label='p_L',marker='2')
    ax1.plot(x, z1_1_C, label='o_C',marker='1')
    ax1.plot(x, z1_p_C, label='p_C',marker='2')
    
    ax1.set(xlabel='model',ylabel='f1 scores')
    ax1.set_title('MSRA')
    ax1.legend(loc='best')
    
    
    # Weibo
    z2_1_L = [52.84, 54.57, 54.22]
    z2_p_L = [57.10, 57.11, None]
    z2_1_C = [55.30, 55.68, 56.10]
    z2_p_C = [58.68, 58.72, None]
    ax2.plot(x, z2_1_L, label='o_L',marker='1')
    ax2.plot(x, z2_p_L, label='p_L',marker='2')
    ax2.plot(x, z2_1_C, label='o_C',marker='1')
    ax2.plot(x, z2_p_C, label='p_C',marker='2')
    
    ax2.set(xlabel='model',ylabel='f1 scores')
    ax2.set_title('Weibo')
    ax2.legend(loc='best')
    
    
    # Literature
    z3_1_L = [74.28, 75.26, 75.99]
    z3_p_L = [74.88, 75.19, None]
    z3_1_C = [76.98, 77.31, 77.54]
    z3_p_C = [75.41, 75.76, None]
    ax3.plot(x, z3_1_L, label='o_L',marker='1')
    ax3.plot(x, z3_p_L, label='p_L',marker='2')
    ax3.plot(x, z3_1_C, label='o_C',marker='1')
    ax3.plot(x, z3_p_C, label='p_C',marker='2')
    
    ax3.set(xlabel='model',ylabel='f1 scores')
    ax3.set_title('Literature')
    ax3.legend(loc='best')
    
    
    # Resume 
    z4_1_L = [29.61, 32.13, 32.26]
    z4_p_L = [46.21, 46.78, None]
    z4_1_C = [31.47, 32.53, 32.43]
    z4_p_C = [47.81, 49.03, None]
    ax4.plot(x, z4_1_L, label='o_L',marker='1')
    ax4.plot(x, z4_p_L, label='p_L',marker='2')
    ax4.plot(x, z4_1_C, label='o_C',marker='1')
    ax4.plot(x, z4_p_C, label='p_C',marker='2')
    
    ax4.set(xlabel='model',ylabel='f1 scores')
    ax4.set_title('Resume')
    ax4.legend(loc='best')
    
    
    # E_commerce
    z5_1_L = [79.17,79.85, 79.24]
    z5_p_L = [78.18, 78.16, None]
    z5_1_C = [80.32, 81.71, 80.54]
    z5_p_C = [79.14, 79.72, None]
    ax5.plot(x, z5_1_L, label='o_L',marker='1')
    ax5.plot(x, z5_p_L, label='p_L',marker='2')
    ax5.plot(x, z5_1_C, label='o_C',marker='1')
    ax5.plot(x, z5_p_C, label='p_C',marker='2')
    
    ax5.set(xlabel='model',ylabel='f1 scores')
    ax5.set_title('E-commerce')
    ax5.legend(loc='best')
    
    
    # CLUENER 
    z6_1_L = [75.31,76.48,76.85]
    z6_p_L = [71.55,72.63, None]
    z6_1_C = [75.75, 76.82,78.25]
    z6_p_C = [72.28, 72.64, None]
    ax6.plot(x, z6_1_L, label='o_L',marker='1')
    ax6.plot(x, z6_p_L, label='p_L',marker='2')
    ax6.plot(x, z6_1_C, label='o_C',marker='1')
    ax6.plot(x, z6_p_C, label='p_C',marker='2')
    
    ax6.set(xlabel='model',ylabel='f1 scores')
    ax6.set_title('CLUENER')
    ax6.legend(loc='best')
    
    
    # Novel
    z7_1_L = [65.80,68.97, 67.08]
    z7_p_L = [57.24, 58.62, None]
    z7_1_C = [67.54, 65.75, 63.70]
    z7_p_C = [54.99, 55.65, None]
    ax7.plot(x, z7_1_L, label='o_L',marker='1')
    ax7.plot(x, z7_p_L, label='p_L',marker='2')
    ax7.plot(x, z7_1_C, label='o_C',marker='1')
    ax7.plot(x, z7_p_C, label='p_C',marker='2')
    
    ax7.set(xlabel='model',ylabel='f1 scores')
    ax7.set_title('Novel')
    ax7.legend(loc='best')
    
    # Finace 
    z8_1_L = [88.34, 88.63, 88.64]
    z8_p_L = [89.49, 90.29, None]
    z8_1_C = [87.92,89.51,88.89]
    z8_p_C = [87.74,88.90, None]
    ax8.plot(x, z8_1_L, label='o_L',marker='1')
    ax8.plot(x, z8_p_L, label='p_L',marker='2')
    ax8.plot(x, z8_1_C, label='o_C',marker='1')
    ax8.plot(x, z8_p_C, label='p_C',marker='2')
    
    ax8.set(xlabel='model',ylabel='f1 scores')
    ax8.set_title('Finace')
    ax8.legend(loc='best')
    
    plt.savefig(output)
    plt.show()

# %%
draw_all_graph()
